# %%
import pandas as pd
import os
df=pd.read_excel('E:/telechargements/plantnet_300K/Book.xlsx') 
df2 = df.iloc[:, 0].str.split(',', expand=True)
df2=df2.iloc[:,0]
df2[0]
path='E:/telechargements/plantnet_300K/images_train'
folders=os.listdir(path)
for i in range(1081):
    originale=path+'/'+folders[i]
    print(originale)
    new=path+'/'+df2[i]
    print(new)
    os.rename(originale,new)
# Out:
# E:/telechargements/plantnet_300K/images_train/1355868
# E:/telechargements/plantnet_300K/images_train/1355868_out
# E:/telechargements/plantnet_300K/images_train/1355920
# E:/telechargements/plantnet_300K/images_train/1355920_out
# E:/telechargements/plantnet_300K/images_train/1355932
# E:/telechargements/plantnet_300K/images_train/1355932_in
# E:/telechargements/plantnet_300K/images_train/1355936
# E:/telechargements/plantnet_300K/images_train/1355936_out
# E:/telechargements/plantnet_300K/images_train/1355937
# E:/telechargements/plantnet_300K/images_train/1355937_out
# E:/telechargements/plantnet_300K/images_train/1355955
# E:/telechargements/plantnet_300K/images_train/1355955_in
# E:/telechargements/plantnet_300K/images_train/1355959
# E:/telechargements/plantnet_300K/images_train/1355959_in
# E:/telechargements/plantnet_300K/images_train/1355961
# E:/telechargements/plantnet_300K/images_train/1355961_out
# E:/telechargements/plantnet_300K/images_train/1355978
# ...

# %%
path='E:/telechargements/plantnet_300K/images_train'
folders=os.listdir(path)
for folder in folders:
    test=folder.find("in")
    if(test!=-1):
        os.replace(path+'/'+folder, path+'/IN/'+folder)
